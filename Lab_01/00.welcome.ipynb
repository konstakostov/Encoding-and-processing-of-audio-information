# %% [markdown]
# # **Кодиране и обработка на аудио информация**

# %% [markdown]
# ## ЛУ 1. "*Представяне на аудио информация в цифров вид. Формати за запис*"

# %% [markdown]
# ### В това упражнение ще бъдат разгледани програмни реализации на следните задачи:

# %% [markdown]
# #### ***I. Aудио информация в цифров вид***
# 1. Генериране на синусоиден сигнал
# 2. Генериране на акорд
# 3. Генериране на кратка мелодия

# %% [markdown]
# #### ***II. Формати за съхранение на цифрово аудио***
# 1. Запазване на аудио сегмент в WAV файл.
# 2. Изследване на параметри на WAV файл.
# 3. Преобразуване на WAV файл.

# %% [markdown]
# #### ***III. Аудио обработка***
# 1. Обработка на WAV файл с филтри
# 2. Обработка на WAV файл с ауио ефекти

# %% [markdown]
# #### ***IV. Визуализация на аудио сигнали***
# 1. АЧХ
# 2. Спектрограма
