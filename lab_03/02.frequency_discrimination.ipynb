# %% [markdown]
# # Честотна отличимост

# %% [markdown]
# #### Import required libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Audio

# %% [markdown]
# ### Задачи за изпълнение
#
# #### Генерирайте синусоидални сигнал с близки честоти и ги визуализирайте
#
# ##### **Стъпка 1. Генериране на синусоидални вълни**
# - Честота на дискретизация: 44 100 Hz;
# - Продължителност: 2 s;
# - Честоти (Ако факултетният ви номер е четен използвайте четните честоти, а ако е нечетен - нечетните честоти):
#     1. 1000 Hz, 1002 Hz
#     2. 1000 Hz, 1004 Hz
#     3. 1000 Hz, 1006 Hz
#     4. 1002 Hz, 1004 Hz
#     5. 1002 Hz, 1006 Hz
#     6. 1004 Hz, 1006 Hz
#     7. 1004 Hz, 1008 Hz
#     8. 1006 Hz, 1010 Hz
#     9. 1010 Hz, 1012 Hz
#     10. 1014 Hz, 1016 Hz
# - Не забравяйте да изчислите t (time array);
# - Конкатенирайте двата сигнала.
#
# ##### **Стъпка 2. Генерирайте графики на получените синусоидални вълни**
# Графиката да бъде на първите 1000 отчета от 2та сигнала.
# Запазете полученият резултат.

# %%
# Sampling rate in Hz
?

# Duration in seconds
?

# Time array
?

# First sine wave frequency
?

# Second sine wave frequency
?

# Generate the sine waves
?
?
?


# Plot the two sine waves
plt.figure(figsize=(10, 4))
plt.plot(?[:1000], ?[:1000], label='ADD MY VALUE HERE DO NOT IGNORE ME!!!')  
plt.plot(?[:1000], ?[:1000], label='ADD MY VALUE HERE DO NOT IGNORE ME!!!')
plt.title('Sine Waves')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)
plt.show()

# Concatenate the two sine waves
concat_wave = np.concatenate((?, ?))

Audio(?, rate=?)

# %% [markdown]
# ### Задачи за изпълнение
#
# #### Beat Frequency
#
# ##### **Стъпка 1. Генериране на синусоидални вълни**
# - Честота на дискретизация: 44 100 Hz;
# - Продължителност: 2 s;
# - Честоти (Ако факултетният ви номер е четен използвайте четните честоти, а ако е нечетен - нечетните честоти.):
#     1. 440 Hz, 450 Hz - Beat Frequency: 10 Hz
#     2. 500 Hz, 510 Hz - Beat Frequency: 10 Hz
#     3. 600 Hz, 620 Hz - Beat Frequency: 20 Hz
#     4. 800 Hz, 820 Hz - Beat Frequency: 20 Hz
#     5. 1000 Hz, 1020 Hz - Beat Frequency: 20 Hz
#     6. 1200 Hz, 1240 Hz - Beat Frequency: 40 Hz
#     7. 1500 Hz, 1550 Hz - Beat Frequency: 50 Hz
#     8. 2000 Hz, 2025 Hz - Beat Frequency: 25 Hz
#     9. 2500 Hz, 2550 Hz - Beat Frequency: 50 Hz
#     10. 3000 Hz, 3060 Hz - Beat Frequency: 60 Hz
# - Не забравяйте да изчислите t (time array);
# - Съберете двата сигнала.
#
# ##### **Стъпка 2. Генерирайте графики на получените синусоидални вълни**
# Графиката да бъде на първите 1000 отчета от 2та сигнала.
# Запазете полученият резултат.

# %%
# Sampling rate in Hz
?

# Duration in seconds
?

# Time array
?

# First sine wave frequency
?

# Second sine wave frequency
?

# Generate the sine waves
?
?
?

# Combine the two sine waves
combined_wave = ? + ?

# Visualize the combined wave to see the beating pattern
plt.figure(figsize=(10, 4))
plt.plot(?[:1000], ?[:1000])
plt.title('Combined Sine Wave - Beat Frequency')
plt.xlabel('Time [s]')
plt.ylabel('Amplitude')
plt.grid(True)
plt.show()

Audio(?, rate=?)
